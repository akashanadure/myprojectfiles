# %%
#Variables

a = 14
print(a)
# Out:
# 14

# %%
b = ["Hello world!"]
print(b)
# Out:
# ['Hello world!']

# %% [markdown]
# #This is a note

# %%
[]
# Out:
# []

# %%
c = 10
print(a+c)
# Out:
# 24

# %%
a = 20
print(c+a)
# Out:
# 30

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# list

# %%
type(c)
# Out:
# int

# %%
a = True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
a = 7
type(a)
# Out:
# int

# %%
x = 15
y = 4
z = x+y
print(z)
print(type(z))
# Out:
# 19
# <class 'int'>
