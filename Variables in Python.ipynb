# %%
x = 15
y = 4
z = x + y
print(z)
print(type(z))
# Out:
# 19
# <class 'int'>

# %%
x = "101"
y = "2"
z = x + y
print(z)
print(type(z))
# Out:
# 1012
# <class 'str'>

# %% [markdown]
# #Array or List Variables

# %%
#A simple array or integers
a = [1,2,3]
print(a)
# Out:
# [1, 2, 3]

# %%
#Storing variables of different types is possible
b = ["Text",4,2.5]
print(b)
# Out:
# ['Text', 4, 2.5]

# %%
print(a[2])
# Out:
# 3

# %%
print(b[2])
# Out:
# 2.5

# %%
a
# Out:
# [1, 2, 3]

# %%
len(a)
# Out:
# 3

# %%
a[0] = 3

# %%
#Slicing lists is a technique used to get elements from, before or between different indices
print("All elements: ",a[:])
# Out:
# All elements:  [3, 2, 3]

# %%
print("All elements from the 3rd position onward: ",a[2:])
# Out:
# All elements from the 3rd position onward:  [3]

# %%
print("All elements from the 2nd and 4th position: ",a[1:3])
# Out:
# All elements from the 2nd and 4th position:  [2, 3]

# %%
print("All elements before the last position: ",a[:-1])
# Out:
# All elements before the last position:  [3, 2]

# %% [markdown]
# #Dictionaries

# %%
#creating a dictionary
country_info = {"name" : "Japan",
                "capital" : "Tokyo"}
print(country_info)
print(country_info["name"])
print(country_info["capital"])
# Out:
# {'name': 'Japan', 'capital': 'Tokyo'}
# Japan
# Tokyo

# %%
#We can store multiple values and easily add information to our dictionary
country_info["population"] = "126.8M"
print(country_info)
# Out:
# {'name': 'Japan', 'capital': 'Tokyo', 'population': '126.8M'}

# %%
country_info['population'] = '100M'
print(country_info)
# Out:
# {'name': 'Japan', 'capital': 'Tokyo', 'population': '100M'}

# %%
country_info['regions'] = ['France', 'Germany', 'Italy', 'Switzerland', 'Lakshadweep', 'Andaman and Nicobar islands', 'Tokyo', 'Netherlands']
print(country_info)
# Out:
# {'name': 'Japan', 'capital': 'Tokyo', 'population': '100M', 'regions': ['France', 'Germany', 'Italy', 'Switzerland', 'Lakshadweep', 'Andaman and Nicobar islands', 'Tokyo', 'Netherlands']}

# %%
country_info['health'] = {"life_expectancy": 84.1, "birth_rate" : 1.44}
print(country_info)
# Out:
# {'name': 'Japan', 'capital': 'Tokyo', 'population': '100M', 'regions': ['France', 'Germany', 'Italy', 'Switzerland', 'Lakshadweep', 'Andaman and Nicobar islands', 'Tokyo', 'Netherlands'], 'health': {'life_expectancy': 84.1, 'birth_rate': 1.44}}

# %%
country_info["health"]["life_expectancy"]
# Out:
# 84.1

# %%
country_info.keys()
# Out:
# dict_keys(['name', 'capital', 'population', 'regions', 'health'])

# %%
country_info.values()
# Out:
# dict_values(['Japan', 'Tokyo', '100M', ['France', 'Germany', 'Italy', 'Switzerland', 'Lakshadweep', 'Andaman and Nicobar islands', 'Tokyo', 'Netherlands'], {'life_expectancy': 84.1, 'birth_rate': 1.44}])
